# %% [markdown]
# Analysing the sales data of the last 12 months for the company RetailEdge

# %% [markdown]
# Loading and understanding the data

# %%
import pandas as pd
import os

# %%
filename = "sales_data.csv"

sales_data = pd.read_csv(filename)
sales_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      5000 non-null   str
#  1   order_date    5000 non-null   str
#  2   customer_id   5000 non-null   str
#  3   region        4980 non-null   str
#  4   category      5000 non-null   str
#  5   product_name  5000 non-null   str
#  6   quantity      5000 non-null   int64
#  7   unit_price    5000 non-null   float64
#  8   discount      4980 non-null   float64
#  9   revenue       5000 non-null   float64
#  10  returned      5000 non-null   bool
# dtypes: bool(1), float64(3), int64(1), str(6)
# memory usage: 395.6 KB

# %%
sales_data.head(10)
# Out:
#     order_id  order_date customer_id region       category     product_name  \
# 0  ORD-13406  2024-11-28   CUST-3898  South    Electronics     Laptop Stand
# 1  ORD-10757  2024-07-09   CUST-2356   East    Electronics        Webcam HD
# 2  ORD-13624  2024-04-26   CUST-4919  North    Electronics        Webcam HD
# 3  ORD-14544  2024-05-01   CUST-1906  South  Home & Garden  Scented Candles
# 4  ORD-13235  2024-03-21   CUST-4518   West       Clothing     Wool Sweater
# 5  ORD-11868  2024-02-18   CUST-4933   East    Electronics     Laptop Stand
# 6  ORD-12916  2024-10-07   CUST-1446  South       Clothing       Yoga Pants
# 7  ORD-13335  2024-10-02   CUST-1394  North    Electronics        USB-C Hub
# 8  ORD-13527  2024-10-07   CUST-4738  North       Clothing        Rain Coat
# 9  ORD-12827  2024-02-25   CUST-4903  North  Home & Garden     Coffee Maker
#
#    quantity  unit_price  discount  revenue  returned
# 0         1       49.99      0.00    49.99     False
# ...

# %%
sales_data.sample(10)
# Out:
#        order_id  order_date customer_id region       category  \
# 834   ORD-11222  2024-06-15   CUST-2155  South  Home & Garden
# 402   ORD-11434  2024-02-12   CUST-4926   East       Clothing
# 662   ORD-12015  2024-06-08   CUST-4631  South       Clothing
# 4200  ORD-10534  2024-11-13   CUST-2104  South    Electronics
# 3199  ORD-13214  2024-03-23   CUST-4285  North       Clothing
# 2402  ORD-11786  2024-09-15   CUST-3683  North       Clothing
# 3753  ORD-10953  2024-12-06   CUST-1598   East  Home & Garden
# 4302  ORD-14234  2024-01-04   CUST-4084  South  Home & Garden
# 2573  ORD-11541  2024-02-26   CUST-1857  North    Electronics
# 3875  ORD-14409  2024-07-08   CUST-2919   West  Home & Garden
#
#              product_name  quantity  unit_price  discount  revenue  returned
# 834         LED Desk Lamp         1       44.99      0.00    44.99      True
# 402             Rain Coat         2      119.99      0.00   239.98     False
# ...

# %%
sales_data.sample().isnull()
# Out:
#      order_id  order_date  customer_id  region  category  product_name  \
# 754     False       False        False   False     False         False
#
#      quantity  unit_price  discount  revenue  returned
# 754     False       False     False    False     False
